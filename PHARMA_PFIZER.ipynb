# %%
import numpy as np
import pandas as pd

df = pd.read_excel("/home/shravan/Desktop/Datasets/pharma/pfizer/pfizer.xlsx")

print(df.head())
print("\n****\n",df.tail())

print("_________________________________________________________\n\nOPEN \n\tAverage : ",np.mean(df.loc[:]['Open']),"\n\tMaximum : ", np.max(df['Open']),"\n\tMinimum : ", np.min(df['Open']),"\n\tStandard Deviation : ", np.std(df['Open']))
print("\n\nHIGH \n\tAverage : ",np.mean(df.loc[:]['High']),"\n\tMaximum : ", np.max(df['High']),"\n\tMinimum : ", np.min(df['High']),"\n\tStandard Deviation : ", np.std(df['High']))
print("\n\nLOW \n\tAverage : ",np.mean(df.loc[:]['Low']),"\n\tMaximum : ", np.max(df['Low']),"\n\tMinimum : ", np.min(df['Low']),"\n\tStandard Deviation : ", np.std(df['Low']))
print("\n\nCLOSE \n\tAverage : ",np.mean(df.loc[:]['Close']),"\n\tMaximum : ", np.max(df['Close']),"\n\tMinimum : ", np.min(df['Close']),"\n\tStandard Deviation : ", np.std(df['Close']))
print("\n\nVOLUME \n\tAverage : ",np.mean(df.loc[:]['Volume']),"\n\tMaximum : ", np.max(df['Volume']),"\n\tMinimum : ", np.min(df['Volume']),"\n\tStandard Deviation : ", np.std(df['Volume']))

def reverse_data(df):
    date = []
    day = []
    open = []
    high = []
    low = []
    close = []
    volume = []
    for i in range(len(df)-1, -1, -1):
        day.append((len(df)-1)-i)
        date.append(df.loc[i]['Date '])
        open.append(df.loc[i]['Open'])
        high.append(df.loc[i]['High'])
        low.append(df.loc[i]['Low'])
        close.append(df.loc[i]['Close'])
        volume.append(df.loc[i]['Volume'])
    stocks = pd.DataFrame()
    stocks['Day'] = day
    stocks['Date'] = date
    stocks['Open'] = open
    stocks['High'] = high
    stocks['Low'] = low
    stocks['Close'] = close
    stocks['Volume'] = volume
    return stocks

stocks = reverse_data(df)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (30,10)
fig,ax = plt.subplots()

ax.plot(stocks['Day'],stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Pfizer Limited")
plt.show()
# Out:
#          Date     Open     High      Low    Close  Volume
# 0  29-Mar-2019  3300.0  3348.00  3265.00  3326.00   33841
# 1  28-Mar-2019  3251.0  3321.00  3230.00  3290.25   22424
# 2  27-Mar-2019  3220.6  3287.95  3191.05  3267.10   26351
# 3  26-Mar-2019  3165.0  3287.95  3144.00  3230.00   31056
# 4  25-Mar-2019  3166.0  3200.05  3135.00  3180.65   15472
#
# ****
#              Date     Open   High     Low   Close  Volume
# 2717  07-Apr-2008  672.35  694.5  662.15  685.90    5877
# 2718  04-Apr-2008  673.00  684.5  669.00  672.35   14869
# 2719  03-Apr-2008  675.00  691.8  669.10  684.05   11378
# 2720  02-Apr-2008  695.10  720.0  691.00  700.35   16497
# 2721  01-Apr-2008  700.00  700.0  675.00  694.70   14215
# _________________________________________________________
#
# OPEN
# 	Average :  1502.7655951506233
# 	Maximum :  3735.0
# 	Minimum :  450.0
# 	Standard Deviation :  646.3160392814301
#
#
# HIGH
# 	Average :  1524.758082292438
# 	Maximum :  3847.7
# 	Minimum :  454.1
# 	Standard Deviation :  655.7471248643697
#
#
# LOW
# 	Average :  1479.7705547391574
# 	Maximum :  3597.55
# 	Minimum :  435.0
# 	Standard Deviation :  634.510703479229
#
#
# CLOSE
# 	Average :  1501.0212711241725
# 	Maximum :  3731.9
# 	Minimum :  443.95
# 	Standard Deviation :  645.5745746211528
#
#
# VOLUME
# 	Average :  17575.136664217487
# 	Maximum :  645040
# 	Minimum :  75
# 	Standard Deviation :  36688.790495527
#    Day         Date    Open   High     Low   Close  Volume
# 0    0  01-Apr-2008  700.00  700.0  675.00  694.70   14215
# 1    1  02-Apr-2008  695.10  720.0  691.00  700.35   16497
# 2    2  03-Apr-2008  675.00  691.8  669.10  684.05   11378
# 3    3  04-Apr-2008  673.00  684.5  669.00  672.35   14869
# 4    4  07-Apr-2008  672.35  694.5  662.15  685.90    5877
#
# ****
#         Day         Date    Open     High      Low    Close  Volume
# 2717  2717  25-Mar-2019  3166.0  3200.05  3135.00  3180.65   15472
# 2718  2718  26-Mar-2019  3165.0  3287.95  3144.00  3230.00   31056
# 2719  2719  27-Mar-2019  3220.6  3287.95  3191.05  3267.10   26351
# 2720  2720  28-Mar-2019  3251.0  3321.00  3230.00  3290.25   22424
# 2721  2721  29-Mar-2019  3300.0  3348.00  3265.00  3326.00   33841

# %%
from sklearn.preprocessing import MinMaxScaler

def get_normalised_data(data):
    scaler = MinMaxScaler()
    numerical = ['Open','High','Low','Close','Volume']
    data[numerical] = scaler.fit_transform(data[numerical])
    return data

stocks = get_normalised_data(stocks)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
fig,ax = plt.subplots()

ax.plot(stocks['Day'],stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Pfizer Limited")
plt.show()
# Out:
#    Day         Date      Open      High       Low     Close    Volume
# 0    0  01-Apr-2008  0.076104  0.072460  0.075888  0.076263  0.021924
# 1    1  02-Apr-2008  0.074612  0.078353  0.080947  0.077982  0.025462
# 2    2  03-Apr-2008  0.068493  0.070044  0.074023  0.073024  0.017525
# 3    3  04-Apr-2008  0.067884  0.067893  0.073991  0.069466  0.022938
# 4    4  07-Apr-2008  0.067686  0.070839  0.071825  0.073587  0.008996
#
# ****
#         Day         Date      Open      High       Low     Close    Volume
# 2717  2717  25-Mar-2019  0.826788  0.809155  0.853741  0.832342  0.023873
# 2718  2718  26-Mar-2019  0.826484  0.835057  0.856587  0.847352  0.048035
# 2719  2719  27-Mar-2019  0.843409  0.835057  0.871464  0.858635  0.040740
# 2720  2720  28-Mar-2019  0.852664  0.844796  0.883780  0.865676  0.034651
# 2721  2721  29-Mar-2019  0.867580  0.852752  0.894848  0.876549  0.052353

# %%
import math
from IPython.display import display
import time
from keras.layers.core import Dense,Dropout,Activation
from keras.models import Sequential
from keras.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from keras.layers.recurrent import LSTM
from keras.layers.recurrent import GRU
from keras.layers.recurrent import SimpleRNN

#UNROLL_FUNCTION
def unroll(stocks,unroll_length):
    result = []
    for i in range(len(stocks)-unroll_length+1):
        result.append(stocks[i : (i+unroll_length)])
    return np.asarray(result)

#SIMPLERNN_MODEL
def build_model(input_dim,output_dim,return_sequences):
    model = Sequential()
    model.add(SimpleRNN(input_shape = (None,input_dim), units = output_dim, return_sequences = return_sequences))
    model.add(Dropout(0.1))
    model.add(SimpleRNN(units = 100, return_sequences = False))
    model.add(Dense(units = 100))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model

#LSTM_MODEL
def build_lstm_model(input_dim, output_dim, return_sequences):
    model = Sequential()
    model.add(LSTM(input_shape = (None, input_dim), units = output_dim, return_sequences = return_sequences))
    model.add(LSTM(units = 128, return_sequences = False))
    model.add(Dense(units = 200))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model


#GRU_MODEL
def build_gru_model(input_dim, output_dim, return_sequences):
    model = Sequential()
    model.add(GRU(input_shape = (None,input_dim), units = output_dim, return_sequences=return_sequences))
    #model.add(Dropout(0.2))
    model.add(GRU(units=128,return_sequences = False))
    #model.add(Dropout(0.2))
    model.add(Dense(units = 200))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model


def plot_prediction(actual, prediction, title='PFIZER TRADING VS PREDICTIONS', y_label='Price INR', x_label='Trading Days'):
    
    fig = plt.figure()
    ax = fig.add_subplot(111)

    # Add labels
    plt.ylabel(y_label)
    plt.xlabel(x_label)

    # Plot actual and predicted close values
    plt.plot(actual, '#00FF00', label='Adjusted Close')
    plt.plot(prediction, '#0000FF', label='Predicted Close')

    # Set title
    ax.set_title(title)
    ax.legend(loc='upper left')
    plt.show()


#RESULT_STAT_FUNCTION
def err_stat(y_test,preds):
    Error = preds - y_test
    print("Standard Deviation of Error : ", np.std(Error))
    stdErr = np.std(Error)
    DstdErr = stdErr * (np.max(df['Close']) - np.min(df['Close']))
    print("Denormalised Standard Deviation : ", DstdErr)
    print("Ratio of Standard Deviation of Error to Standard Deviation of Stock Price : ", DstdErr/np.std(df['Close']))




#####
#TRAIN_TEST_SPLIT
stocks = stocks.drop(['Date','Day'], axis =1)
stocks.head()

def train_test_split(stocks,unroll_length,prediction_size,prediction_time):
    x_test_start = prediction_size + prediction_time + unroll_length - 1
    
    #train data
    x_train = stocks[0 : (-x_test_start - prediction_time)].to_numpy()
    y_train = stocks[ (unroll_length - 1 + prediction_time) : -x_test_start]['Close'].to_numpy()
    
    #test_data
    x_test = stocks[-x_test_start : -prediction_time].to_numpy()
    y_test = stocks[-prediction_size:]['Close'].to_numpy()

    
    return x_train,x_test,y_train,y_test

prediction_size = 494
prediction_time = 5
unroll_length = 50

x_train,x_test,y_train,y_test = train_test_split(stocks,unroll_length,prediction_size,prediction_time)

x_train = unroll(x_train,unroll_length)
x_test = unroll(x_test,unroll_length)

print("x_train", x_train.shape)
print("y_train", y_train.shape)
print("x_test", x_test.shape)
print("y_test", y_test.shape)

#####
# Out:
# x_train (2120, 50, 5)
# y_train (2120,)
# x_test (494, 50, 5)
# y_test (494,)

# %%
#TRAIN_SIMPLE_RNN_MODEL
model = build_model(input_dim = x_train.shape[-1], output_dim = unroll_length, return_sequences=True)
model.compile(loss = "mean_squared_error", optimizer = 'Adam')
model.fit(x_train, y_train, epochs =50, validation_split = 0.05)

preds = model.predict(x_test)
plot_prediction(y_test, preds)
err_stat(y_test,preds)

trainScore = model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))

#TRAIN_LSTM_MODEL
lstm_model = build_lstm_model(x_train.shape[-1], unroll_length, return_sequences = True)
lstm_model.compile(loss = "mean_squared_error", optimizer = 'Adam')
lstm_model.fit(x_train, y_train, epochs = 50, validation_split = 0.05)

preds_lstm = lstm_model.predict(x_test)
plot_prediction(y_test, preds_lstm)
err_stat(y_test,preds_lstm)

trainScore = lstm_model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))


#TRAIN_GRU_MODEL
gru_model = build_gru_model(x_train.shape[-1], unroll_length, return_sequences = True)
gru_model.compile(loss = "mean_squared_error", optimizer = 'Adam')
gru_model.fit(x_train, y_train, epochs = 50, validation_split = 0.05)

preds_gru = gru_model.predict(x_test)
plot_prediction(y_test, preds_gru)
err_stat(y_test,preds_gru)

trainScore = gru_model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = gru_model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Epoch 1/50
# 63/63 [==============================] - 2s 16ms/step - loss: 0.0912 - val_loss: 0.0019
# Epoch 2/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 3/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 2.1981e-04
# Epoch 4/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 7.0194e-04
# Epoch 5/50
# 63/63 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 9.1159e-04
# Epoch 6/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 7/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.5780e-04
# Epoch 8/50
# 63/63 [==============================] - 1s 11ms/step - loss: 8.9420e-04 - val_loss: 5.4733e-04
# Epoch 9/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 4.3848e-04
# Epoch 10/50
# 63/63 [==============================] - 1s 11ms/step - loss: 7.9892e-04 - val_loss: 0.0014
# Epoch 11/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.4809e-04
# Epoch 12/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 8.2040e-04
# Epoch 13/50
# 63/63 [==============================] - 1s 10ms/step - loss: 7.6224e-04 - val_loss: 5.4913e-04
# Epoch 14/50
# 63/63 [==============================] - 1s 11ms/step - loss: 8.0916e-04 - val_loss: 0.0030
# Epoch 15/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0010 - val_loss: 1.8436e-04
# Epoch 16/50
# 63/63 [==============================] - 1s 10ms/step - loss: 9.5007e-04 - val_loss: 2.4637e-04
# Epoch 17/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.8630e-04 - val_loss: 0.0011
# Epoch 18/50
# 63/63 [==============================] - 1s 11ms/step - loss: 9.1475e-04 - val_loss: 5.6458e-04
# Epoch 19/50
# 63/63 [==============================] - 1s 11ms/step - loss: 9.1713e-04 - val_loss: 5.6777e-04
# Epoch 20/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 1.8035e-04
# Epoch 21/50
# 63/63 [==============================] - 1s 10ms/step - loss: 6.4427e-04 - val_loss: 2.8945e-04
# Epoch 22/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.3271e-04 - val_loss: 3.6233e-04
# Epoch 23/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.9312e-04 - val_loss: 9.9845e-04
# Epoch 24/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.1674e-04 - val_loss: 8.6171e-04
# Epoch 25/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 26/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.6818e-04 - val_loss: 2.6231e-04
# Epoch 27/50
# 63/63 [==============================] - 1s 10ms/step - loss: 7.0096e-04 - val_loss: 0.0017
# Epoch 28/50
# 63/63 [==============================] - 1s 11ms/step - loss: 9.1759e-04 - val_loss: 0.0020
# Epoch 29/50
# 63/63 [==============================] - 1s 10ms/step - loss: 7.2474e-04 - val_loss: 2.1690e-04
# Epoch 30/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.4734e-04 - val_loss: 4.4768e-04
# Epoch 31/50
# 63/63 [==============================] - 1s 10ms/step - loss: 5.5530e-04 - val_loss: 1.9237e-04
# Epoch 32/50
# 63/63 [==============================] - 1s 10ms/step - loss: 6.5340e-04 - val_loss: 4.4078e-04
# Epoch 33/50
# 63/63 [==============================] - 1s 10ms/step - loss: 5.6537e-04 - val_loss: 6.8359e-04
# Epoch 34/50
# 63/63 [==============================] - 1s 10ms/step - loss: 7.9685e-04 - val_loss: 0.0014
# Epoch 35/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.0433e-04 - val_loss: 3.4979e-04
# Epoch 36/50
# 63/63 [==============================] - 1s 11ms/step - loss: 5.7833e-04 - val_loss: 1.9009e-04
# Epoch 37/50
# 63/63 [==============================] - 1s 10ms/step - loss: 5.4456e-04 - val_loss: 3.3804e-04
# Epoch 38/50
# 63/63 [==============================] - 1s 11ms/step - loss: 5.8924e-04 - val_loss: 1.8541e-04
# Epoch 39/50
# 63/63 [==============================] - 1s 10ms/step - loss: 5.4895e-04 - val_loss: 2.7018e-04
# Epoch 40/50
# 63/63 [==============================] - 1s 10ms/step - loss: 7.2994e-04 - val_loss: 0.0019
# Epoch 41/50
# 63/63 [==============================] - 1s 11ms/step - loss: 7.6106e-04 - val_loss: 4.6039e-04
# Epoch 42/50
# 63/63 [==============================] - 1s 11ms/step - loss: 5.8965e-04 - val_loss: 4.7491e-04
# Epoch 43/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.6789e-04 - val_loss: 2.1926e-04
# Epoch 44/50
# 63/63 [==============================] - 1s 10ms/step - loss: 4.7232e-04 - val_loss: 0.0028
# Epoch 45/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.6029e-04 - val_loss: 2.3839e-04
# Epoch 46/50
# 63/63 [==============================] - 1s 11ms/step - loss: 6.3739e-04 - val_loss: 7.9252e-04
# Epoch 47/50
# 63/63 [==============================] - 1s 10ms/step - loss: 5.5279e-04 - val_loss: 3.1255e-04
# Epoch 48/50
# 63/63 [==============================] - 1s 10ms/step - loss: 4.9619e-04 - val_loss: 0.0011
# Epoch 49/50
# 63/63 [==============================] - 1s 10ms/step - loss: 4.9744e-04 - val_loss: 2.2779e-04
# Epoch 50/50
# 63/63 [==============================] - 1s 10ms/step - loss: 5.0557e-04 - val_loss: 2.5116e-04
# Standard Deviation of Error :  0.20566782393635194
# Denormalised Standard Deviation :  676.2255217115285
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  1.0474785536719173
# Train Score: 0.00044136 MSE (0.02100867 RMSE)
# Test Score: 0.00298738 MSE (0.05465696 RMSE)
# Epoch 1/50
# 63/63 [==============================] - 4s 40ms/step - loss: 0.0169 - val_loss: 2.9820e-04
# Epoch 2/50
# 63/63 [==============================] - 2s 29ms/step - loss: 6.0207e-04 - val_loss: 5.8835e-04
# Epoch 3/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.1470e-04 - val_loss: 3.0113e-04
# Epoch 4/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.4295e-04 - val_loss: 8.6314e-04
# Epoch 5/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.9818e-04 - val_loss: 5.8989e-04
# Epoch 6/50
# 63/63 [==============================] - 2s 29ms/step - loss: 6.6595e-04 - val_loss: 2.1424e-04
# Epoch 7/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.4912e-04 - val_loss: 2.1080e-04
# Epoch 8/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.4895e-04 - val_loss: 2.8021e-04
# Epoch 9/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.9308e-04 - val_loss: 3.3835e-04
# Epoch 10/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.9798e-04 - val_loss: 2.1882e-04
# Epoch 11/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.0614e-04 - val_loss: 2.8546e-04
# Epoch 12/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.7149e-04 - val_loss: 1.8883e-04
# Epoch 13/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.7140e-04 - val_loss: 2.6437e-04
# Epoch 14/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.6832e-04 - val_loss: 3.7050e-04
# Epoch 15/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.6921e-04 - val_loss: 2.7276e-04
# Epoch 16/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.7030e-04 - val_loss: 3.1756e-04
# Epoch 17/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.0981e-04 - val_loss: 2.5705e-04
# Epoch 18/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.5838e-04 - val_loss: 4.6041e-04
# Epoch 19/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.8939e-04 - val_loss: 1.7416e-04
# Epoch 20/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.4986e-04 - val_loss: 2.1706e-04
# Epoch 21/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.3942e-04 - val_loss: 2.3499e-04
# Epoch 22/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.9112e-04 - val_loss: 1.6978e-04
# Epoch 23/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.9979e-04 - val_loss: 2.3274e-04
# Epoch 24/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.1953e-04 - val_loss: 1.6110e-04
# Epoch 25/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.1174e-04 - val_loss: 2.6832e-04
# Epoch 26/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.3211e-04 - val_loss: 3.9014e-04
# Epoch 27/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.9109e-04 - val_loss: 2.2310e-04
# Epoch 28/50
# 63/63 [==============================] - 2s 29ms/step - loss: 5.2892e-04 - val_loss: 1.5869e-04
# Epoch 29/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.0505e-04 - val_loss: 1.7288e-04
# Epoch 30/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.0393e-04 - val_loss: 1.7557e-04
# Epoch 31/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.0746e-04 - val_loss: 1.5910e-04
# Epoch 32/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.1705e-04 - val_loss: 1.9928e-04
# Epoch 33/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.6608e-04 - val_loss: 1.5772e-04
# Epoch 34/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.2615e-04 - val_loss: 1.9115e-04
# Epoch 35/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.6691e-04 - val_loss: 3.9382e-04
# Epoch 36/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.9319e-04 - val_loss: 1.7086e-04
# Epoch 37/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.1551e-04 - val_loss: 1.8423e-04
# Epoch 38/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.1390e-04 - val_loss: 4.3970e-04
# Epoch 39/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.1957e-04 - val_loss: 4.1133e-04
# Epoch 40/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.8476e-04 - val_loss: 2.3780e-04
# Epoch 41/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.0510e-04 - val_loss: 4.0421e-04
# Epoch 42/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.2213e-04 - val_loss: 1.9721e-04
# Epoch 43/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.0550e-04 - val_loss: 1.4678e-04
# Epoch 44/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.1054e-04 - val_loss: 1.5132e-04
# Epoch 45/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.3281e-04 - val_loss: 1.8051e-04
# Epoch 46/50
# 63/63 [==============================] - 2s 31ms/step - loss: 3.4881e-04 - val_loss: 6.9931e-04
# Epoch 47/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.5826e-04 - val_loss: 3.4163e-04
# Epoch 48/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.8363e-04 - val_loss: 2.0230e-04
# Epoch 49/50
# 63/63 [==============================] - 2s 32ms/step - loss: 3.2665e-04 - val_loss: 1.5404e-04
# Epoch 50/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.5839e-04 - val_loss: 1.4597e-04
# Standard Deviation of Error :  0.21508926148883153
# Denormalised Standard Deviation :  707.2027373122037
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  1.0954624997851201
# Train Score: 0.00031304 MSE (0.01769301 RMSE)
# Test Score: 0.00211178 MSE (0.04595406 RMSE)
# Epoch 1/50
# 63/63 [==============================] - 4s 39ms/step - loss: 0.0086 - val_loss: 1.6951e-04
# Epoch 2/50
# 63/63 [==============================] - 2s 27ms/step - loss: 4.9989e-04 - val_loss: 3.7939e-04
# Epoch 3/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.1263e-04 - val_loss: 3.4334e-04
# Epoch 4/50
# 63/63 [==============================] - 2s 31ms/step - loss: 4.8084e-04 - val_loss: 2.3314e-04
# Epoch 5/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.5771e-04 - val_loss: 2.6771e-04
# Epoch 6/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.3032e-04 - val_loss: 1.5844e-04
# Epoch 7/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.7322e-04 - val_loss: 2.0291e-04
# Epoch 8/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.3678e-04 - val_loss: 3.0736e-04
# Epoch 9/50
# 63/63 [==============================] - 2s 27ms/step - loss: 4.5654e-04 - val_loss: 2.7045e-04
# Epoch 10/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.2648e-04 - val_loss: 2.0861e-04
# Epoch 11/50
# 63/63 [==============================] - 2s 28ms/step - loss: 3.6886e-04 - val_loss: 4.6613e-04
# Epoch 12/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.6222e-04 - val_loss: 4.5633e-04
# Epoch 13/50
# 63/63 [==============================] - 2s 28ms/step - loss: 5.1071e-04 - val_loss: 2.2914e-04
# Epoch 14/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.5059e-04 - val_loss: 2.0642e-04
# Epoch 15/50
# 63/63 [==============================] - 2s 28ms/step - loss: 3.8878e-04 - val_loss: 1.5523e-04
# Epoch 16/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.3793e-04 - val_loss: 3.3317e-04
# Epoch 17/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.8925e-04 - val_loss: 4.7291e-04
# Epoch 18/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.5242e-04 - val_loss: 2.1836e-04
# Epoch 19/50
# 63/63 [==============================] - 2s 28ms/step - loss: 5.7025e-04 - val_loss: 1.4613e-04
# Epoch 20/50
# 63/63 [==============================] - 2s 31ms/step - loss: 3.5080e-04 - val_loss: 3.0215e-04
# Epoch 21/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.9598e-04 - val_loss: 2.2742e-04
# Epoch 22/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.4203e-04 - val_loss: 2.3802e-04
# Epoch 23/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.4037e-04 - val_loss: 1.6742e-04
# Epoch 24/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.7955e-04 - val_loss: 1.4821e-04
# Epoch 25/50
# 63/63 [==============================] - 2s 32ms/step - loss: 3.7358e-04 - val_loss: 4.4801e-04
# Epoch 26/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.4504e-04 - val_loss: 1.4326e-04
# Epoch 27/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.0928e-04 - val_loss: 3.2856e-04
# Epoch 28/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.7456e-04 - val_loss: 3.2866e-04
# Epoch 29/50
# 63/63 [==============================] - 2s 30ms/step - loss: 4.0877e-04 - val_loss: 1.7390e-04
# Epoch 30/50
# 63/63 [==============================] - 2s 31ms/step - loss: 3.8108e-04 - val_loss: 2.5877e-04
# Epoch 31/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.8292e-04 - val_loss: 2.4230e-04
# Epoch 32/50
# 63/63 [==============================] - 2s 28ms/step - loss: 3.9882e-04 - val_loss: 0.0013
# Epoch 33/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.4515e-04 - val_loss: 1.5367e-04
# Epoch 34/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.7809e-04 - val_loss: 1.5316e-04
# Epoch 35/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.1805e-04 - val_loss: 1.3984e-04
# Epoch 36/50
# 63/63 [==============================] - 2s 28ms/step - loss: 3.6134e-04 - val_loss: 2.3970e-04
# Epoch 37/50
# 63/63 [==============================] - 2s 29ms/step - loss: 4.2705e-04 - val_loss: 1.3446e-04
# Epoch 38/50
# 63/63 [==============================] - 2s 29ms/step - loss: 3.6760e-04 - val_loss: 2.2276e-04
# Epoch 39/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.9124e-04 - val_loss: 1.7303e-04
# Epoch 40/50
# 63/63 [==============================] - 2s 28ms/step - loss: 4.7359e-04 - val_loss: 1.8571e-04
# Epoch 41/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.7978e-04 - val_loss: 1.8775e-04
# Epoch 42/50
# 63/63 [==============================] - 2s 28ms/step - loss: 3.9180e-04 - val_loss: 1.8643e-04
# Epoch 43/50
# 63/63 [==============================] - 2s 27ms/step - loss: 4.0287e-04 - val_loss: 6.1330e-04
# Epoch 44/50
# 63/63 [==============================] - 2s 30ms/step - loss: 5.4047e-04 - val_loss: 1.4038e-04
# Epoch 45/50
# 63/63 [==============================] - 2s 32ms/step - loss: 4.0065e-04 - val_loss: 3.3632e-04
# Epoch 46/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.8970e-04 - val_loss: 1.3876e-04
# Epoch 47/50
# 63/63 [==============================] - 2s 31ms/step - loss: 3.3823e-04 - val_loss: 1.6152e-04
# Epoch 48/50
# 63/63 [==============================] - 2s 28ms/step - loss: 3.8202e-04 - val_loss: 2.3819e-04
# Epoch 49/50
# 63/63 [==============================] - 2s 30ms/step - loss: 3.8357e-04 - val_loss: 3.0908e-04
# Epoch 50/50
# 63/63 [==============================] - 2s 31ms/step - loss: 3.9797e-04 - val_loss: 1.3999e-04
# Standard Deviation of Error :  0.21532346738849206
# Denormalised Standard Deviation :  707.9727945999925
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  1.0966553244688382
# Train Score: 0.00031906 MSE (0.01786230 RMSE)
# Test Score: 0.00159807 MSE (0.03997584 RMSE)
