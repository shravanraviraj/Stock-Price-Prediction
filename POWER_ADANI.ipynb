# %%
import numpy as np
import pandas as pd

df = pd.read_excel("/home/shravan/Desktop/Datasets/power/adanipower/ADANI_POWER.xlsx")

print(df.head())
print("\n****\n",df.tail())

print("_________________________________________________________\n\nOPEN \n\tAverage : ",np.mean(df.loc[:]['Open']),"\n\tMaximum : ", np.max(df['Open']),"\n\tMinimum : ", np.min(df['Open']),"\n\tStandard Deviation : ", np.std(df['Open']))
print("\n\nHIGH \n\tAverage : ",np.mean(df.loc[:]['High']),"\n\tMaximum : ", np.max(df['High']),"\n\tMinimum : ", np.min(df['High']),"\n\tStandard Deviation : ", np.std(df['High']))
print("\n\nLOW \n\tAverage : ",np.mean(df.loc[:]['Low']),"\n\tMaximum : ", np.max(df['Low']),"\n\tMinimum : ", np.min(df['Low']),"\n\tStandard Deviation : ", np.std(df['Low']))
print("\n\nCLOSE \n\tAverage : ",np.mean(df.loc[:]['Close']),"\n\tMaximum : ", np.max(df['Close']),"\n\tMinimum : ", np.min(df['Close']),"\n\tStandard Deviation : ", np.std(df['Close']))
print("\n\nVOLUME \n\tAverage : ",np.mean(df.loc[:]['Volume']),"\n\tMaximum : ", np.max(df['Volume']),"\n\tMinimum : ", np.min(df['Volume']),"\n\tStandard Deviation : ", np.std(df['Volume']))
# Out:
#          Date    Open   High    Low  Close    Volume
# 0  29-Mar-2019  47.05  50.35  46.80   48.2  20253763
# 1  28-Mar-2019  46.95  47.60  46.60   46.9   8521212
# 2  27-Mar-2019  48.10  48.45  46.50   46.9   7826448
# 3  26-Mar-2019  47.90  48.80  47.40   47.8   9457346
# 4  25-Mar-2019  47.60  48.35  47.25   47.6   8340825
#
# ****
#              Date    Open    High     Low   Close     Volume
# 2379  26-Aug-2009  103.0  107.50  102.85  105.10   17158838
# 2380  25-Aug-2009  102.5  103.15  101.00  102.75   11720267
# 2381  24-Aug-2009  103.9  104.40  101.55  103.10   13665282
# 2382  21-Aug-2009   99.9  103.90   98.00  103.15   33717842
# 2383  20-Aug-2009  108.0  110.00   98.30  100.10  164328256
# _________________________________________________________
#
# OPEN
# 	Average :  57.68164848993287
# 	Maximum :  145.9
# 	Minimum :  15.45
# 	Standard Deviation :  33.79181677763348
#
#
# HIGH
# 	Average :  58.715205536912585
# 	Maximum :  145.9
# 	Minimum :  16.1
# 	Standard Deviation :  34.15062606471684
#
#
# LOW
# 	Average :  56.495952181208224
# 	Maximum :  140.8
# 	Minimum :  15.15
# 	Standard Deviation :  33.35098014844251
#
#
# CLOSE
# 	Average :  57.527810402684544
# 	Maximum :  143.35
# 	Minimum :  15.45
# 	Standard Deviation :  33.697285679294275
#
#
# VOLUME
# 	Average :  7495716.120805369
# 	Maximum :  164328256
# 	Minimum :  45665
# 	Standard Deviation :  11473911.431994706

# %%
def reverse_data(df):
    date = []
    day = []
    open = []
    high = []
    low = []
    close = []
    volume = []
    for i in range(len(df)-1, -1, -1):
        day.append((len(df)-1)-i)
        date.append(df.loc[i]['Date '])
        open.append(df.loc[i]['Open'])
        high.append(df.loc[i]['High'])
        low.append(df.loc[i]['Low'])
        close.append(df.loc[i]['Close'])
        volume.append(df.loc[i]['Volume'])
    stocks = pd.DataFrame()
    stocks['Day'] = day
    stocks['Date'] = date
    stocks['Open'] = open
    stocks['High'] = high
    stocks['Low'] = low
    stocks['Close'] = close
    stocks['Volume'] = volume
    return stocks

stocks = reverse_data(df)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
fig,ax = plt.subplots()

ax.plot(stocks['Day'],stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Adani Power Ltd.")
plt.show()
# Out:
#    Day         Date   Open    High     Low   Close     Volume
# 0    0  20-Aug-2009  108.0  110.00   98.30  100.10  164328256
# 1    1  21-Aug-2009   99.9  103.90   98.00  103.15   33717842
# 2    2  24-Aug-2009  103.9  104.40  101.55  103.10   13665282
# 3    3  25-Aug-2009  102.5  103.15  101.00  102.75   11720267
# 4    4  26-Aug-2009  103.0  107.50  102.85  105.10   17158838
#
# ****
#         Day         Date   Open   High    Low  Close    Volume
# 2379  2379  25-Mar-2019  47.60  48.35  47.25   47.6   8340825
# 2380  2380  26-Mar-2019  47.90  48.80  47.40   47.8   9457346
# 2381  2381  27-Mar-2019  48.10  48.45  46.50   46.9   7826448
# 2382  2382  28-Mar-2019  46.95  47.60  46.60   46.9   8521212
# 2383  2383  29-Mar-2019  47.05  50.35  46.80   48.2  20253763

# %%
from sklearn.preprocessing import MinMaxScaler

def get_normalised_data(data):
    scaler = MinMaxScaler()
    numerical = ['Open','High','Low','Close','Volume']
    data[numerical] = scaler.fit_transform(data[numerical])
    return data

stocks = get_normalised_data(stocks)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
fig,ax = plt.subplots()

ax.plot(stocks['Day'],stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Adani Power Ltd.")
plt.show()
# Out:
#    Day         Date      Open      High       Low     Close    Volume
# 0    0  20-Aug-2009  0.709467  0.723421  0.661759  0.661845  1.000000
# 1    1  21-Aug-2009  0.647374  0.676425  0.659371  0.685692  0.204965
# 2    2  24-Aug-2009  0.678038  0.680277  0.687624  0.685301  0.082904
# 3    3  25-Aug-2009  0.667305  0.670647  0.683247  0.682565  0.071064
# 4    4  26-Aug-2009  0.671138  0.704160  0.697971  0.700938  0.104169
#
# ****
#         Day         Date      Open      High       Low     Close    Volume
# 2379  2379  25-Mar-2019  0.246455  0.248459  0.255472  0.251368  0.050493
# 2380  2380  26-Mar-2019  0.248754  0.251926  0.256665  0.252932  0.057290
# 2381  2381  27-Mar-2019  0.250287  0.249230  0.249503  0.245895  0.047362
# 2382  2382  28-Mar-2019  0.241472  0.242681  0.250298  0.245895  0.051591
# 2383  2383  29-Mar-2019  0.242238  0.263867  0.251890  0.256059  0.123008

# %%
import math
from IPython.display import display
import time
from keras.layers.core import Dense,Dropout,Activation
from keras.layers.recurrent import SimpleRNN
from keras.models import Sequential
from keras.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold


def unroll(stocks,unroll_length):
    result = []
    for i in range(len(stocks)-unroll_length+1):
        result.append(stocks[i : (i+unroll_length)])
    return np.asarray(result)

def build_model(input_dim,output_dim,return_sequences):
    model = Sequential()
    model.add(SimpleRNN(input_shape = (None,input_dim), units = output_dim, return_sequences = return_sequences))
    model.add(Dropout(0.1))
    model.add(SimpleRNN(units = 100, return_sequences = False))
    model.add(Dense(units = 100))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model

stocks = stocks.drop(['Date','Day'], axis =1)

stocks.head()
# Out:
#        Open      High       Low     Close    Volume
# 0  0.709467  0.723421  0.661759  0.661845  1.000000
# 1  0.647374  0.676425  0.659371  0.685692  0.204965
# 2  0.678038  0.680277  0.687624  0.685301  0.082904
# 3  0.667305  0.670647  0.683247  0.682565  0.071064
# 4  0.671138  0.704160  0.697971  0.700938  0.104169

# %%
print(stocks.shape)

def train_test_split(stocks,unroll_length,prediction_size,prediction_time):
    x_test_start = prediction_size + prediction_time + unroll_length - 1
    
    #train data
    x_train = stocks[0 : (-x_test_start - prediction_time)].to_numpy()
    y_train = stocks[ (unroll_length - 1 + prediction_time) : -x_test_start]['Close'].to_numpy()
    
    #test_data
    x_test = stocks[-x_test_start : -prediction_time].to_numpy()
    y_test = stocks[-prediction_size:]['Close'].to_numpy()

    
    return x_train,x_test,y_train,y_test
# Out:
# (2384, 5)

# %%
prediction_size = 248
prediction_time = 5
unroll_length = 50

x_train,x_test,y_train,y_test = train_test_split(stocks,unroll_length,prediction_size,prediction_time)

x_train = unroll(x_train,unroll_length)
x_test = unroll(x_test,unroll_length)

print("x_train", x_train.shape)
print("y_train", y_train.shape)
print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2028, 50, 5)
# y_train (2028,)
# x_test (248, 50, 5)
# y_test (248,)

# %%
model = build_model(input_dim = x_train.shape[-1], output_dim = unroll_length, return_sequences=True)

model.compile(loss = "mean_squared_error", optimizer = 'Adam')

model.fit(x_train, y_train, epochs =50, validation_split = 0.05)
# Out:
# Epoch 1/50
# 61/61 [==============================] - 3s 28ms/step - loss: 0.1097 - val_loss: 8.9352e-04
# Epoch 2/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0049 - val_loss: 5.8170e-04
# Epoch 3/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 4/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 5.5192e-04
# Epoch 5/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0026 - val_loss: 0.0040
# Epoch 6/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0025 - val_loss: 4.5048e-04
# Epoch 7/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0019 - val_loss: 6.0343e-04
# Epoch 8/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 9/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 10/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 5.5172e-04
# Epoch 11/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0016 - val_loss: 8.4749e-04
# Epoch 12/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 13/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0024 - val_loss: 5.8352e-04
# Epoch 14/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0019 - val_loss: 5.1987e-04
# Epoch 15/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0017 - val_loss: 5.2166e-04
# Epoch 16/50
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0014 - val_loss: 7.3898e-04
# Epoch 17/50
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0017 - val_loss: 5.7280e-04
# Epoch 18/50
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0017 - val_loss: 5.5163e-04
# Epoch 19/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 4.9876e-04
# Epoch 20/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0019 - val_loss: 5.2672e-04
# Epoch 21/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0016 - val_loss: 4.8415e-04
# Epoch 22/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 23/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 24/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 25/50
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0024 - val_loss: 5.0700e-04
# Epoch 26/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0018 - val_loss: 5.8178e-04
# Epoch 27/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 28/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 6.0538e-04
# Epoch 29/50
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 30/50
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 31/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 4.4763e-04
# Epoch 32/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 4.3961e-04
# Epoch 33/50
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0014 - val_loss: 5.3187e-04
# Epoch 34/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0015 - val_loss: 4.4707e-04
# Epoch 35/50
# 61/61 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 4.7051e-04
# Epoch 36/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0014 - val_loss: 5.8922e-04
# Epoch 37/50
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0017 - val_loss: 5.3549e-04
# Epoch 38/50
# 61/61 [==============================] - 1s 18ms/step - loss: 0.0019 - val_loss: 5.3552e-04
# Epoch 39/50
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0012 - val_loss: 5.8086e-04
# Epoch 40/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 4.6930e-04
# Epoch 41/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 4.5522e-04
# Epoch 42/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 5.6610e-04
# Epoch 43/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 5.0388e-04
# Epoch 44/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 4.2400e-04
# Epoch 45/50
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 4.5387e-04
# Epoch 46/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 5.0148e-04
# Epoch 47/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 4.0419e-04
# Epoch 48/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 3.5873e-04
# Epoch 49/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 4.8445e-04
# Epoch 50/50
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 4.1064e-04

# %%
preds = model.predict(x_test)

def plot_prediction(actual, prediction, title='ADANI POWER TRADING VS PREDICTIONS', y_label='Price INR', x_label='Trading Days'):
    """
    Plots train, test and prediction
    :param actual: DataFrame containing actual data
    :param prediction: DataFrame containing predicted values
    :param title:  Title of the plot
    :param y_label: yLabel of the plot
    :param x_label: xLabel of the plot
    :return: prints a Pyplot againts items and their closing value
    """
    fig = plt.figure()
    ax = fig.add_subplot(111)

    # Add labels
    plt.ylabel(y_label)
    plt.xlabel(x_label)

    # Plot actual and predicted close values

    plt.plot(actual, '#00FF00', label='Adjusted Close')
    plt.plot(prediction, '#0000FF', label='Predicted Close')

    # Set title
    ax.set_title(title)
    ax.legend(loc='upper left')


    plt.show()
    
plot_prediction(y_test, preds)

# %%
trainScore = model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))



Error = preds - y_test
print("\nStandard Deviation of Error : ", np.std(Error))
stdErr = np.std(Error)

DstdErr = stdErr * (np.max(df['Close']) - np.min(df['Close']))
print("\nDenormalised Standard Deviation : ", DstdErr)

print("\nRatio of Standard Deviation of Error to Standard Deviation of Stock Price : ", DstdErr/np.std(df['Close']))
# Out:
# Train Score: 0.00090982 MSE (0.03016320 RMSE)
# Test Score: 0.00182383 MSE (0.04270636 RMSE)
#
# Standard Deviation of Error :  0.14133783873668554
#
# Denormalised Standard Deviation :  18.077109574422078
#
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  0.5364559551314184

# %%
from keras.layers.recurrent import LSTM
def build_lstm_model(input_dim, output_dim, return_sequences):
    model = Sequential()
    model.add(LSTM(input_shape = (None, input_dim), units = output_dim, return_sequences = return_sequences))
    model.add(LSTM(units = 128, return_sequences = False))
    model.add(Dense(units = 200))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model

lstm_model = build_lstm_model(x_train.shape[-1], unroll_length, return_sequences = True)
lstm_model.compile(loss = "mean_squared_error", optimizer = 'Adam')
lstm_model.fit(x_train, y_train, epochs = 50, validation_split = 0.05)
# Out:
# Epoch 1/50
# 61/61 [==============================] - 5s 49ms/step - loss: 0.0424 - val_loss: 7.2489e-04
# Epoch 2/50
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - val_loss: 6.7693e-04
# Epoch 3/50
# 61/61 [==============================] - 2s 39ms/step - loss: 0.0013 - val_loss: 6.3808e-04
# Epoch 4/50
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0013 - val_loss: 6.7254e-04
# Epoch 5/50
# 61/61 [==============================] - 2s 37ms/step - loss: 0.0014 - val_loss: 6.3140e-04
# Epoch 6/50
# 61/61 [==============================] - 2s 38ms/step - loss: 0.0012 - val_loss: 6.9599e-04
# Epoch 7/50
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0013 - val_loss: 6.4245e-04
# Epoch 8/50
# 61/61 [==============================] - 3s 46ms/step - loss: 0.0012 - val_loss: 6.7067e-04
# Epoch 9/50
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0013 - val_loss: 5.2028e-04
# Epoch 10/50
# 61/61 [==============================] - 3s 46ms/step - loss: 0.0011 - val_loss: 6.9603e-04
# Epoch 11/50
# 61/61 [==============================] - 2s 38ms/step - loss: 0.0011 - val_loss: 7.1485e-04
# Epoch 12/50
# 61/61 [==============================] - 3s 45ms/step - loss: 0.0012 - val_loss: 9.7047e-04
# Epoch 13/50
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - val_loss: 5.0040e-04
# Epoch 14/50
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0012 - val_loss: 5.3037e-04
# Epoch 15/50
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0011 - val_loss: 6.2205e-04
# Epoch 16/50
# 61/61 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 7.1698e-04
# Epoch 17/50
# 61/61 [==============================] - 3s 50ms/step - loss: 9.5391e-04 - val_loss: 4.4837e-04
# Epoch 18/50
# 61/61 [==============================] - 4s 59ms/step - loss: 0.0010 - val_loss: 4.6190e-04
# Epoch 19/50
# 61/61 [==============================] - 3s 47ms/step - loss: 0.0015 - val_loss: 9.2080e-04
# Epoch 20/50
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0010 - val_loss: 4.8106e-04
# Epoch 21/50
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0010 - val_loss: 5.4272e-04
# Epoch 22/50
# 61/61 [==============================] - 2s 39ms/step - loss: 9.7518e-04 - val_loss: 4.3246e-04
# Epoch 23/50
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0011 - val_loss: 8.4629e-04
# Epoch 24/50
# 61/61 [==============================] - 2s 39ms/step - loss: 9.6176e-04 - val_loss: 5.6485e-04
# Epoch 25/50
# 61/61 [==============================] - 2s 40ms/step - loss: 9.9353e-04 - val_loss: 3.8071e-04
# Epoch 26/50
# 61/61 [==============================] - 2s 38ms/step - loss: 9.9845e-04 - val_loss: 5.4372e-04
# Epoch 27/50
# 61/61 [==============================] - 2s 39ms/step - loss: 9.4392e-04 - val_loss: 7.5597e-04
# Epoch 28/50
# 61/61 [==============================] - 2s 37ms/step - loss: 9.3862e-04 - val_loss: 5.7277e-04
# Epoch 29/50
# 61/61 [==============================] - 2s 40ms/step - loss: 0.0011 - val_loss: 6.4936e-04
# Epoch 30/50
# 61/61 [==============================] - 2s 39ms/step - loss: 8.7839e-04 - val_loss: 4.8124e-04
# Epoch 31/50
# 61/61 [==============================] - 2s 37ms/step - loss: 0.0010 - val_loss: 3.9882e-04
# Epoch 32/50
# 61/61 [==============================] - 2s 37ms/step - loss: 8.8309e-04 - val_loss: 4.3104e-04
# Epoch 33/50
# 61/61 [==============================] - 3s 41ms/step - loss: 8.6425e-04 - val_loss: 4.2458e-04
# Epoch 34/50
# 61/61 [==============================] - 3s 46ms/step - loss: 8.5046e-04 - val_loss: 4.7083e-04
# Epoch 35/50
# 61/61 [==============================] - 2s 40ms/step - loss: 9.9568e-04 - val_loss: 5.5606e-04
# Epoch 36/50
# 61/61 [==============================] - 2s 33ms/step - loss: 7.9457e-04 - val_loss: 6.9847e-04
# Epoch 37/50
# 61/61 [==============================] - 2s 34ms/step - loss: 9.5070e-04 - val_loss: 3.5715e-04
# Epoch 38/50
# 61/61 [==============================] - 3s 45ms/step - loss: 9.0887e-04 - val_loss: 4.2084e-04
# Epoch 39/50
# 61/61 [==============================] - 2s 34ms/step - loss: 9.5009e-04 - val_loss: 4.3918e-04
# Epoch 40/50
# 61/61 [==============================] - 2s 36ms/step - loss: 8.3027e-04 - val_loss: 3.4544e-04
# Epoch 41/50
# 61/61 [==============================] - 2s 34ms/step - loss: 8.3836e-04 - val_loss: 3.7269e-04
# Epoch 42/50
# 61/61 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 3.9146e-04
# Epoch 43/50
# 61/61 [==============================] - 2s 34ms/step - loss: 7.8915e-04 - val_loss: 4.7332e-04
# Epoch 44/50
# 61/61 [==============================] - 2s 34ms/step - loss: 9.3929e-04 - val_loss: 4.9305e-04
# Epoch 45/50
# 61/61 [==============================] - 2s 34ms/step - loss: 8.1730e-04 - val_loss: 8.3014e-04
# Epoch 46/50
# 61/61 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 3.7937e-04
# Epoch 47/50
# 61/61 [==============================] - 2s 33ms/step - loss: 9.2438e-04 - val_loss: 4.3864e-04
# Epoch 48/50
# 61/61 [==============================] - 2s 35ms/step - loss: 9.5539e-04 - val_loss: 3.3844e-04
# Epoch 49/50
# 61/61 [==============================] - 2s 38ms/step - loss: 8.2163e-04 - val_loss: 3.3811e-04
# Epoch 50/50
# 61/61 [==============================] - 2s 39ms/step - loss: 0.0012 - val_loss: 4.0541e-04

# %%
preds_lstm = lstm_model.predict(x_test)
plot_prediction(y_test, preds_lstm)


trainScore = lstm_model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))

Error_lstm = preds_lstm - y_test
print("Standard Deviation of Error : ", np.std(Error_lstm))
stdErr_lstm = np.std(Error_lstm)

DstdErr_lstm = stdErr_lstm * (np.max(df['Close']) - np.min(df['Close']))
print("Denormalised Standard Deviation : ", DstdErr_lstm)

print("Ratio of Standard Deviation of Error to Standard Deviation of Stock Price : ", DstdErr_lstm/np.std(df['Close']))
# Out:
# Train Score: 0.00083405 MSE (0.02887986 RMSE)
# Test Score: 0.00145197 MSE (0.03810477 RMSE)
# Standard Deviation of Error :  0.13222767678332248
# Denormalised Standard Deviation :  16.911919860586945
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  0.5018778076531751

# %%
from keras.layers.recurrent import GRU

def build_gru_model(input_dim, output_dim, return_sequences):
    model = Sequential()
    model.add(GRU(input_shape = (None,input_dim), units = output_dim, return_sequences=return_sequences))
    #model.add(Dropout(0.2))
    model.add(GRU(units=128,return_sequences = False))
    #model.add(Dropout(0.2))
    model.add(Dense(units = 200))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model

gru_model = build_gru_model(x_train.shape[-1], unroll_length, return_sequences =True)

gru_model.compile(loss = "mean_squared_error", optimizer = 'Adam')

gru_model.fit(x_train,y_train, epochs=50, validation_split = 0.05)

preds_gru = gru_model.predict(x_test)
plot_prediction(y_test, preds_lstm)


trainScore = gru_model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = gru_model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))



Error_gru = preds_gru - y_test
print("Standard Deviation of Error : ", np.std(Error_lstm))
stdErr_gru = np.std(Error_gru)

DstdErr_gru = stdErr_gru * (np.max(df['Close']) - np.min(df['Close']))
print("Denormalised Standard Deviation : ", DstdErr_gru)

print("Ratio of Standard Deviation of Error to Standard Deviation of Stock Price : ", DstdErr_gru/np.std(df['Close']))
# Out:
# Epoch 1/50
# 61/61 [==============================] - 5s 48ms/step - loss: 0.0254 - val_loss: 5.0953e-04
# Epoch 2/50
# 61/61 [==============================] - 3s 42ms/step - loss: 9.5120e-04 - val_loss: 4.5124e-04
# Epoch 3/50
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0012 - val_loss: 5.7164e-04
# Epoch 4/50
# 61/61 [==============================] - 2s 34ms/step - loss: 9.5321e-04 - val_loss: 4.6829e-04
# Epoch 5/50
# 61/61 [==============================] - 2s 35ms/step - loss: 9.2642e-04 - val_loss: 6.5746e-04
# Epoch 6/50
# 61/61 [==============================] - 2s 36ms/step - loss: 9.7588e-04 - val_loss: 4.1009e-04
# Epoch 7/50
# 61/61 [==============================] - 2s 34ms/step - loss: 9.5094e-04 - val_loss: 4.8544e-04
# Epoch 8/50
# 61/61 [==============================] - 2s 37ms/step - loss: 9.7640e-04 - val_loss: 4.4051e-04
# Epoch 9/50
# 61/61 [==============================] - 3s 42ms/step - loss: 9.8396e-04 - val_loss: 7.6708e-04
# Epoch 10/50
# 61/61 [==============================] - 3s 42ms/step - loss: 8.9369e-04 - val_loss: 6.4204e-04
# Epoch 11/50
# 61/61 [==============================] - 2s 39ms/step - loss: 9.0501e-04 - val_loss: 7.5225e-04
# Epoch 12/50
# 61/61 [==============================] - 2s 32ms/step - loss: 8.8785e-04 - val_loss: 3.5807e-04
# Epoch 13/50
# 61/61 [==============================] - 2s 31ms/step - loss: 9.9565e-04 - val_loss: 5.9810e-04
# Epoch 14/50
# 61/61 [==============================] - 2s 38ms/step - loss: 9.4487e-04 - val_loss: 3.5748e-04
# Epoch 15/50
# 61/61 [==============================] - 2s 31ms/step - loss: 8.6748e-04 - val_loss: 5.6761e-04
# Epoch 16/50
# 61/61 [==============================] - 2s 29ms/step - loss: 8.7014e-04 - val_loss: 4.5033e-04
# Epoch 17/50
# 61/61 [==============================] - 2s 29ms/step - loss: 9.2204e-04 - val_loss: 3.7185e-04
# Epoch 18/50
# 61/61 [==============================] - 2s 31ms/step - loss: 9.1665e-04 - val_loss: 4.4212e-04
# Epoch 19/50
# 61/61 [==============================] - 2s 30ms/step - loss: 7.8007e-04 - val_loss: 3.8419e-04
# Epoch 20/50
# 61/61 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 3.6829e-04
# Epoch 21/50
# 61/61 [==============================] - 2s 30ms/step - loss: 8.7834e-04 - val_loss: 3.7356e-04
# Epoch 22/50
# 61/61 [==============================] - 2s 30ms/step - loss: 8.3354e-04 - val_loss: 8.8150e-04
# Epoch 23/50
# 61/61 [==============================] - 2s 30ms/step - loss: 0.0010 - val_loss: 3.6063e-04
# Epoch 24/50
# 61/61 [==============================] - 2s 30ms/step - loss: 9.8137e-04 - val_loss: 3.5203e-04
# Epoch 25/50
# 61/61 [==============================] - 2s 30ms/step - loss: 8.5019e-04 - val_loss: 4.2409e-04
# Epoch 26/50
# 61/61 [==============================] - 2s 30ms/step - loss: 8.9841e-04 - val_loss: 3.4478e-04
# Epoch 27/50
# 61/61 [==============================] - 2s 30ms/step - loss: 0.0012 - val_loss: 3.7992e-04
# Epoch 28/50
# 61/61 [==============================] - 2s 30ms/step - loss: 7.9488e-04 - val_loss: 5.5599e-04
# Epoch 29/50
# 61/61 [==============================] - 2s 30ms/step - loss: 9.3042e-04 - val_loss: 3.7406e-04
# Epoch 30/50
# 61/61 [==============================] - 2s 33ms/step - loss: 7.8577e-04 - val_loss: 6.2706e-04
# Epoch 31/50
# 61/61 [==============================] - 2s 40ms/step - loss: 8.6686e-04 - val_loss: 4.3840e-04
# Epoch 32/50
# 61/61 [==============================] - 2s 39ms/step - loss: 8.2797e-04 - val_loss: 6.4457e-04
# Epoch 33/50
# 61/61 [==============================] - 2s 31ms/step - loss: 9.1287e-04 - val_loss: 4.6168e-04
# Epoch 34/50
# 61/61 [==============================] - 2s 41ms/step - loss: 8.4266e-04 - val_loss: 3.6611e-04
# Epoch 35/50
# 61/61 [==============================] - 3s 43ms/step - loss: 8.8171e-04 - val_loss: 4.3002e-04
# Epoch 36/50
# 61/61 [==============================] - 2s 35ms/step - loss: 8.2375e-04 - val_loss: 4.8578e-04
# Epoch 37/50
# 61/61 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 3.8483e-04
# Epoch 38/50
# 61/61 [==============================] - 2s 34ms/step - loss: 9.0742e-04 - val_loss: 3.4239e-04
# Epoch 39/50
# 61/61 [==============================] - 2s 31ms/step - loss: 9.4692e-04 - val_loss: 5.0919e-04
# Epoch 40/50
# 61/61 [==============================] - 3s 46ms/step - loss: 9.2515e-04 - val_loss: 3.1779e-04
# Epoch 41/50
# 61/61 [==============================] - 2s 40ms/step - loss: 9.1934e-04 - val_loss: 3.8295e-04
# Epoch 42/50
# 61/61 [==============================] - 2s 37ms/step - loss: 9.8108e-04 - val_loss: 3.4583e-04
# Epoch 43/50
# 61/61 [==============================] - 2s 33ms/step - loss: 9.0268e-04 - val_loss: 4.1955e-04
# Epoch 44/50
# 61/61 [==============================] - 2s 35ms/step - loss: 9.4692e-04 - val_loss: 3.5237e-04
# Epoch 45/50
# 61/61 [==============================] - 3s 47ms/step - loss: 8.8534e-04 - val_loss: 4.2887e-04
# Epoch 46/50
# 61/61 [==============================] - 2s 41ms/step - loss: 8.1812e-04 - val_loss: 4.4994e-04
# Epoch 47/50
# 61/61 [==============================] - 2s 35ms/step - loss: 8.8746e-04 - val_loss: 4.5689e-04
# Epoch 48/50
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0010 - val_loss: 4.0711e-04
# Epoch 49/50
# 61/61 [==============================] - 2s 31ms/step - loss: 9.2403e-04 - val_loss: 3.7858e-04
# Epoch 50/50
# 61/61 [==============================] - 2s 34ms/step - loss: 8.7272e-04 - val_loss: 4.8224e-04
# Train Score: 0.00076332 MSE (0.02762820 RMSE)
# Test Score: 0.00151088 MSE (0.03886998 RMSE)
# Standard Deviation of Error :  0.13222767678332248
# Denormalised Standard Deviation :  17.293367933371
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  0.513197653305267
